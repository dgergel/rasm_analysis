# %%
# %matplotlib inline
import xarray as xr

# %%
t = xr.open_dataset('t_cpl.nc')
albedo = xr.open_dataset('albedo_cpl.nc')

# %%
t['x2a_Sx_t'].where(t['x2a_Sx_t'] > 274).plot()

# %%
albedo['x2a_Sx_anidf'].where(albedo['x2a_Sx_anidf'] > 0).plot()
